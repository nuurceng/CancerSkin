# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pickle5

# %%
from PIL import  Image
import matplotlib.pyplot as plt
import pandas as pd # veri işleme - data processing, csv file 
import numpy as np
import seaborn as sns

from keras.models import load_model,Model
from keras.layers import MaxPool2D, Dropout, Dense
from keras.optimizers import Adam

from keras.utils.np_utils import to_categorical 
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint ,EarlyStopping

#from keras import applications
from keras.preprocessing.image import ImageDataGenerator
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

from keras import layers

import pickle5 as pickle

from sklearn.metrics import classification_report

skin_df = pd.read_csv("/content/drive/MyDrive/cancer_skin/HAM10000_metadata.csv")
skin_df.head()#data hakkında bilgi 10015
skin_df.info()#
print('------------------------------------------------------------------------')
sns.countplot(x = "dx", data = skin_df)#dağılımları nasıl olduğu tablo
plt.show()

lesion_dict = {     
                  'nv': 'Melanocytic nevi',
                  'mel': 'Melanoma',
                  'bkl': 'Benign keratosis-like lesions',
                  'bcc': 'Basal cell carcinoma',
                  'akiec': 'Actinic keratoses',
                  'vasc': 'Vascular lesions',
                  'df': 'Dermatofibroma'
              }

skin_df['cell_type'] = skin_df['dx'].map(lesion_dict.get)
skin_df['dx_idx'] = pd.Categorical(skin_df['cell_type']).codes

fig, ax1 = plt.subplots(1, 1, figsize = (10, 5))
sns.countplot(y='dx_idx',data=skin_df, hue="cell_type",ax=ax1)
plt.show()

print('------------------------------------------------------------------------')
print('Toplam resim sayısı =',len(skin_df))
print('Melanositik nevüs diğer etiketlere göre çok daha sık olduğu için dengesizdir.')

sayi =skin_df['cell_type'].value_counts()
print(sayi)
print('------------------------------------------------------------------------')

#% ön işlem veriset
data_folder_name = "/content/drive/MyDrive/cancer_skin/HAM10000_images_part_1/"
ext = ".jpg"
skin_df["path"] = [ data_folder_name + i + ext for i in skin_df["image_id"]] #for döngüsü ile  resim id erişim yolunu elde etti
"""skin_df["image"] = skin_df["path"].map( lambda x: np.asarray(Image.open(x).resize((128,128))))#array olarak yükledi
plt.imshow(skin_df["image"][0])
skin_df["dx_idx"] = pd.Categorical(skin_df["dx"]).codes#sayılara çevirdi - integer 
skin_df.to_pickle("/content/drive/MyDrive/cancer_skin/skin_dff.pkl")#kaydetme - veri depolandı"""

#% yükle pkl
skin_df=pickle.load( open ( "/content/drive/MyDrive/cancer_skin/skin_dff.pkl" ,  "rb" ))
plt.imshow(skin_df["image"][0])
print(skin_df['image'][0].shape)



Y = to_categorical(skin_df["dx_idx"], num_classes = 7)
print("Shape one-hot encoding: ", Y.shape)



X_train, X_test, Y_train, Y_test = train_test_split(skin_df,Y,test_size=0.20)
X_train = np.asarray(X_train['image'].tolist())
X_test = np.asarray(X_test['image'].tolist())

print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)


X_train,X_val, Y_train,Y_val = train_test_split(X_train,Y_train,test_size=0.10, random_state=42)

X_train  = X_train.reshape(X_train.shape[0],128,128,3)
X_test  = X_test.reshape(X_test.shape[0],128,128,3)
X_val  = X_val.reshape(X_val.shape[0],128,128,3)


print ("son eğitim örnekleri sayısı = " + str(X_train.shape[0]))
print ("test örnekleri sayısı = " + str(X_test.shape[0]))
print ("X_train şekli:" + str(X_train.shape))
print ("Y_train şekli:" + str(Y_train.shape))
print ("X_test şekli: " + str(X_test.shape))
print ("Y_test şekli: " + str(Y_test.shape))

print("X_val shape" + str(X_val.shape))
print("Y_val shape" + str(Y_val.shape))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Toplam resim sayısı = 10015
# Melanositik nevüs diğer etiketlere göre çok daha sık olduğu için dengesizdir.
# Melanocytic nevi                 6705
# Melanoma                         1113
# Benign keratosis-like lesions    1099
# Basal cell carcinoma              514
# Actinic keratoses                 327
# Vascular lesions                  142
# Dermatofibroma                    115
# Name: cell_type, dtype: int64
# ------------------------------------------------------------------------
# (128, 128, 3)
# Shape one-hot encoding:  (10015, 7)
# (8012, 128, 128, 3)
# (8012, 7)
# (2003, 128, 128, 3)
# (2003, 7)
# son eğitim örnekleri sayısı = 7210
# test örnekleri sayısı = 2003
# X_train şekli:(7210, 128, 128, 3)
# Y_train şekli:(7210, 7)
# X_test şekli: (2003, 128, 128, 3)
# Y_test şekli: (2003, 7)
# X_val shape(802, 128, 128, 3)
# Y_val shape(802, 7)

# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input
 
pre_trained_model = InceptionV3(input_shape=(128, 128, 3), include_top=False, weights="imagenet")
 
for layer in pre_trained_model.layers:
    print(layer.name)
    layer.trainable = False
    
print(len(pre_trained_model.layers))
 
last_layer = pre_trained_model.get_layer('mixed10')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output
 
 
x = layers.GlobalMaxPooling2D()(last_output)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(7, activation='softmax')(x)
model = Model(pre_trained_model.input, x)


optimizer = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
 
model.summary()
 
 
train_datagen = ImageDataGenerator(rotation_range=60, width_shift_range=0.2, height_shift_range=0.2,
                                   shear_range=0.2, zoom_range=0.2, fill_mode='nearest')
 
train_datagen.fit(X_train)
 
val_datagen = ImageDataGenerator()
val_datagen.fit(X_val)
 
batch_size = 32
epochs = 10
history = model.fit(train_datagen.flow(X_train,Y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = val_datagen.flow(X_val, Y_val),
                              verbose = 1, steps_per_epoch=(X_train.shape[0] // batch_size), 
                              validation_steps=(X_val.shape[0] // batch_size))
 
for layer in pre_trained_model.layers:
    layer.trainable = True
 
optimizer = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min' ,verbose=1)
checkpoint = ModelCheckpoint('/content/drive/MyDrive/cancer_skin/checkpoint.h5', monitor='val_acc', verbose=1, 
                             save_best_only=True, mode='max')

learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=3, verbose=1, factor=0.5, 
                                            min_lr=0.000001, cooldown=2)
 
model.summary()
 
 
batch_size = 64
epochs = 40
history = model.fit(train_datagen.flow(X_train,Y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = val_datagen.flow(X_val, Y_val),
                              verbose = 1, steps_per_epoch=(X_train.shape[0] // batch_size),
                              validation_steps=(X_val.shape[0] // batch_size),
                              callbacks=[learning_rate_reduction, early_stopping, checkpoint])
 
 
model.save("/content/drive/MyDrive/cancer_skin/InceptionV3.h5")
# Out:
# input_2
# conv2d_94
# batch_normalization_94
# activation_94
# conv2d_95
# batch_normalization_95
# activation_95
# conv2d_96
# batch_normalization_96
# activation_96
# max_pooling2d_4
# conv2d_97
# batch_normalization_97
# activation_97
# conv2d_98
# batch_normalization_98
# activation_98
# max_pooling2d_5
# conv2d_102
# batch_normalization_102
# activation_102
# conv2d_100
# conv2d_103
# batch_normalization_100
# batch_normalization_103
# activation_100
# activation_103
# average_pooling2d_9
# conv2d_99
# conv2d_101
# conv2d_104
# conv2d_105
# batch_normalization_99
# batch_normalization_101
# batch_normalization_104
# batch_normalization_105
# activation_99
# activation_101
# activation_104
# activation_105
# mixed0
# conv2d_109
# batch_normalization_109
# activation_109
# conv2d_107
# conv2d_110
# batch_normalization_107
# batch_normalization_110
# activation_107
# activation_110
# average_pooling2d_10
# conv2d_106
# conv2d_108
# conv2d_111
# conv2d_112
# batch_normalization_106
# batch_normalization_108
# batch_normalization_111
# batch_normalization_112
# activation_106
# activation_108
# activation_111
# activation_112
# mixed1
# conv2d_116
# batch_normalization_116
# activation_116
# conv2d_114
# conv2d_117
# batch_normalization_114
# batch_normalization_117
# activation_114
# activation_117
# average_pooling2d_11
# conv2d_113
# conv2d_115
# conv2d_118
# conv2d_119
# batch_normalization_113
# batch_normalization_115
# batch_normalization_118
# batch_normalization_119
# activation_113
# activation_115
# activation_118
# activation_119
# mixed2
# conv2d_121
# batch_normalization_121
# activation_121
# conv2d_122
# batch_normalization_122
# activation_122
# conv2d_120
# conv2d_123
# batch_normalization_120
# batch_normalization_123
# activation_120
# activation_123
# max_pooling2d_6
# mixed3
# conv2d_128
# batch_normalization_128
# activation_128
# conv2d_129
# batch_normalization_129
# activation_129
# conv2d_125
# conv2d_130
# batch_normalization_125
# batch_normalization_130
# activation_125
# activation_130
# conv2d_126
# conv2d_131
# batch_normalization_126
# batch_normalization_131
# activation_126
# activation_131
# average_pooling2d_12
# conv2d_124
# conv2d_127
# conv2d_132
# conv2d_133
# batch_normalization_124
# batch_normalization_127
# batch_normalization_132
# batch_normalization_133
# activation_124
# activation_127
# activation_132
# activation_133
# mixed4
# conv2d_138
# batch_normalization_138
# activation_138
# conv2d_139
# batch_normalization_139
# activation_139
# conv2d_135
# conv2d_140
# batch_normalization_135
# batch_normalization_140
# activation_135
# activation_140
# conv2d_136
# conv2d_141
# batch_normalization_136
# batch_normalization_141
# activation_136
# activation_141
# average_pooling2d_13
# conv2d_134
# conv2d_137
# conv2d_142
# conv2d_143
# batch_normalization_134
# batch_normalization_137
# batch_normalization_142
# batch_normalization_143
# activation_134
# activation_137
# activation_142
# activation_143
# mixed5
# conv2d_148
# batch_normalization_148
# activation_148
# conv2d_149
# batch_normalization_149
# activation_149
# conv2d_145
# conv2d_150
# batch_normalization_145
# batch_normalization_150
# activation_145
# activation_150
# conv2d_146
# conv2d_151
# batch_normalization_146
# batch_normalization_151
# activation_146
# activation_151
# average_pooling2d_14
# conv2d_144
# conv2d_147
# conv2d_152
# conv2d_153
# batch_normalization_144
# batch_normalization_147
# batch_normalization_152
# batch_normalization_153
# activation_144
# activation_147
# activation_152
# activation_153
# mixed6
# conv2d_158
# batch_normalization_158
# activation_158
# conv2d_159
# batch_normalization_159
# activation_159
# conv2d_155
# conv2d_160
# batch_normalization_155
# batch_normalization_160
# activation_155
# activation_160
# conv2d_156
# conv2d_161
# batch_normalization_156
# batch_normalization_161
# activation_156
# activation_161
# average_pooling2d_15
# conv2d_154
# conv2d_157
# conv2d_162
# conv2d_163
# batch_normalization_154
# batch_normalization_157
# batch_normalization_162
# batch_normalization_163
# activation_154
# activation_157
# activation_162
# activation_163
# mixed7
# conv2d_166
# batch_normalization_166
# activation_166
# conv2d_167
# batch_normalization_167
# activation_167
# conv2d_164
# conv2d_168
# batch_normalization_164
# batch_normalization_168
# activation_164
# activation_168
# conv2d_165
# conv2d_169
# batch_normalization_165
# batch_normalization_169
# activation_165
# activation_169
# max_pooling2d_7
# mixed8
# conv2d_174
# batch_normalization_174
# activation_174
# conv2d_171
# conv2d_175
# batch_normalization_171
# batch_normalization_175
# activation_171
# activation_175
# conv2d_172
# conv2d_173
# conv2d_176
# conv2d_177
# average_pooling2d_16
# conv2d_170
# batch_normalization_172
# batch_normalization_173
# batch_normalization_176
# batch_normalization_177
# conv2d_178
# batch_normalization_170
# activation_172
# activation_173
# activation_176
# activation_177
# batch_normalization_178
# activation_170
# mixed9_0
# concatenate_2
# activation_178
# mixed9
# conv2d_183
# batch_normalization_183
# activation_183
# conv2d_180
# conv2d_184
# batch_normalization_180
# batch_normalization_184
# activation_180
# activation_184
# conv2d_181
# conv2d_182
# conv2d_185
# conv2d_186
# average_pooling2d_17
# conv2d_179
# batch_normalization_181
# batch_normalization_182
# batch_normalization_185
# batch_normalization_186
# conv2d_187
# batch_normalization_179
# activation_181
# activation_182
# activation_185
# activation_186
# batch_normalization_187
# activation_179
# mixed9_1
# concatenate_3
# activation_187
# mixed10
# 311
# last layer output shape: (None, 2, 2, 2048)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 63, 63, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 63, 63, 32)   96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 63, 63, 32)   0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 61, 61, 32)   9216        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 61, 61, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 61, 61, 32)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 61, 61, 64)   18432       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 61, 61, 64)   192         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 61, 61, 64)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 64)   0           activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 30, 30, 80)   5120        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 30, 30, 80)   240         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 30, 30, 80)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 28, 28, 192)  138240      activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 28, 28, 192)  576         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 28, 28, 192)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 192)  0           activation_98[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 13, 13, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 13, 13, 64)   192         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 13, 13, 64)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 13, 13, 48)   9216        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 13, 13, 96)   55296       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 13, 13, 48)   144         conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 13, 13, 96)   288         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 13, 13, 48)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 13, 13, 96)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 13, 13, 192)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 13, 13, 64)   12288       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 13, 13, 64)   76800       activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 13, 13, 96)   82944       activation_103[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 13, 13, 32)   6144        average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 13, 13, 64)   192         conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 13, 13, 64)   192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 13, 13, 96)   288         conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 13, 13, 32)   96          conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 13, 13, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 13, 13, 64)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 13, 13, 96)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 13, 13, 32)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 13, 13, 256)  0           activation_99[0][0]
#                                                                  activation_101[0][0]
#                                                                  activation_104[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 13, 13, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 13, 13, 64)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 13, 13, 64)   0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 13, 13, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 13, 13, 96)   55296       activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 13, 13, 48)   144         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 13, 13, 96)   288         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 13, 13, 48)   0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 13, 13, 96)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10 (AveragePo (None, 13, 13, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 13, 13, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 13, 13, 64)   76800       activation_107[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 13, 13, 96)   82944       activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 13, 13, 64)   16384       average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 13, 13, 64)   192         conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 13, 13, 64)   192         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 13, 13, 96)   288         conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 13, 13, 64)   192         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 13, 13, 64)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 13, 13, 64)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 13, 13, 96)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 13, 13, 64)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 13, 13, 288)  0           activation_106[0][0]
#                                                                  activation_108[0][0]
#                                                                  activation_111[0][0]
#                                                                  activation_112[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 13, 13, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 13, 13, 64)   192         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 13, 13, 64)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 13, 13, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 13, 13, 96)   55296       activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 13, 13, 48)   144         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 13, 13, 96)   288         conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 13, 13, 48)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 13, 13, 96)   0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 13, 13, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 13, 13, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 13, 13, 64)   76800       activation_114[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 13, 13, 96)   82944       activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 13, 13, 64)   18432       average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 13, 13, 64)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 13, 13, 64)   192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 13, 13, 96)   288         conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 13, 13, 64)   192         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 13, 13, 64)   0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 13, 13, 64)   0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 13, 13, 96)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 13, 13, 64)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 13, 13, 288)  0           activation_113[0][0]
#                                                                  activation_115[0][0]
#                                                                  activation_118[0][0]
#                                                                  activation_119[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 13, 13, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 13, 13, 64)   192         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 13, 13, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 13, 13, 96)   55296       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 13, 13, 96)   288         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 13, 13, 96)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 6, 6, 384)    995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 6, 6, 96)     82944       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 6, 6, 384)    1152        conv2d_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 6, 6, 96)     288         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 6, 6, 384)    0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 6, 6, 96)     0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 6, 6, 288)    0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 6, 6, 768)    0           activation_120[0][0]
#                                                                  activation_123[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 6, 6, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 6, 6, 128)    384         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 6, 6, 128)    0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 6, 6, 128)    114688      activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 6, 6, 128)    384         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 6, 6, 128)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 6, 6, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 6, 6, 128)    114688      activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 6, 6, 128)    384         conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 6, 6, 128)    384         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 6, 6, 128)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 6, 6, 128)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 6, 6, 128)    114688      activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 6, 6, 128)    114688      activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 6, 6, 128)    384         conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 6, 6, 128)    384         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 6, 6, 128)    0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 6, 6, 128)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 6, 6, 768)    0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 6, 6, 192)    147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 6, 6, 192)    172032      activation_126[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 6, 6, 192)    172032      activation_131[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 6, 6, 192)    147456      average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 6, 6, 192)    576         conv2d_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 6, 6, 192)    576         conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 6, 6, 192)    576         conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 6, 6, 192)    576         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 6, 6, 192)    0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 6, 6, 192)    0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 6, 6, 192)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 6, 6, 192)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 6, 6, 768)    0           activation_124[0][0]
#                                                                  activation_127[0][0]
#                                                                  activation_132[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 6, 6, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 6, 6, 160)    480         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 6, 6, 160)    0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 6, 6, 160)    179200      activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 6, 6, 160)    480         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 6, 6, 160)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 6, 6, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 6, 6, 160)    179200      activation_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 6, 6, 160)    480         conv2d_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 6, 6, 160)    480         conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 6, 6, 160)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 6, 6, 160)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 6, 6, 160)    179200      activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 6, 6, 160)    179200      activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 6, 6, 160)    480         conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 6, 6, 160)    480         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 6, 6, 160)    0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 6, 6, 160)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 6, 6, 768)    0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 6, 6, 192)    147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 6, 6, 192)    215040      activation_136[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 6, 6, 192)    215040      activation_141[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 6, 6, 192)    147456      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 6, 6, 192)    576         conv2d_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 6, 6, 192)    576         conv2d_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 6, 6, 192)    576         conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 6, 6, 192)    576         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 6, 6, 192)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 6, 6, 192)    0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 6, 6, 192)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 6, 6, 192)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 6, 6, 768)    0           activation_134[0][0]
#                                                                  activation_137[0][0]
#                                                                  activation_142[0][0]
#                                                                  activation_143[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 6, 6, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 6, 6, 160)    480         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 6, 6, 160)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 6, 6, 160)    179200      activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 6, 6, 160)    480         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 6, 6, 160)    0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 6, 6, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 6, 6, 160)    179200      activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 6, 6, 160)    480         conv2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 6, 6, 160)    480         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 6, 6, 160)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 6, 6, 160)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 6, 6, 160)    179200      activation_145[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 6, 6, 160)    179200      activation_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 6, 6, 160)    480         conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 6, 6, 160)    480         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 6, 6, 160)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 6, 6, 160)    0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 6, 6, 768)    0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 6, 6, 192)    147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 6, 6, 192)    215040      activation_146[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 6, 6, 192)    215040      activation_151[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 6, 6, 192)    147456      average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 6, 6, 192)    576         conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 6, 6, 192)    576         conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 6, 6, 192)    576         conv2d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 6, 6, 192)    576         conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 6, 6, 192)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 6, 6, 192)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 6, 6, 192)    0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 6, 6, 192)    0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 6, 6, 768)    0           activation_144[0][0]
#                                                                  activation_147[0][0]
#                                                                  activation_152[0][0]
#                                                                  activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 6, 6, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 6, 6, 192)    576         conv2d_158[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 6, 6, 192)    0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 6, 6, 192)    258048      activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 6, 6, 192)    576         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 6, 6, 192)    0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 6, 6, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 6, 6, 192)    258048      activation_159[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 2, 2, 768)    0           activation_172[0][0]
#                                                                  activation_173[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2, 2, 768)    0           activation_176[0][0]
#                                                                  activation_177[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 2, 2, 192)    0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 2, 2, 2048)   0           activation_170[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 2, 2, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 2, 2, 448)    1344        conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 2, 2, 448)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 2, 2, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 2, 2, 384)    1548288     activation_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 2, 2, 384)    1152        conv2d_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 2, 2, 384)    1152        conv2d_184[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 2, 2, 384)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 2, 2, 384)    0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 2, 2, 384)    442368      activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 2, 2, 384)    442368      activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 2, 2, 384)    442368      activation_184[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 2, 2, 384)    442368      activation_184[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, 2, 2, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 2, 2, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 2, 2, 384)    1152        conv2d_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 2, 2, 384)    1152        conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 2, 2, 384)    1152        conv2d_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 2, 2, 384)    1152        conv2d_186[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 2, 2, 192)    393216      average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 2, 2, 320)    960         conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 2, 2, 384)    0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 2, 2, 384)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 2, 2, 384)    0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 2, 2, 384)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 2, 2, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 2, 2, 320)    0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 2, 2, 768)    0           activation_181[0][0]
#                                                                  activation_182[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2, 2, 768)    0           activation_185[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 2, 2, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 2, 2, 2048)   0           activation_179[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 7)            3591        dropout_1[0][0]
# ==================================================================================================
# Total params: 22,855,463
# Trainable params: 22,821,031
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Epoch 1/40
# 112/112 [==============================] - 51s 282ms/step - loss: 1.1683 - acc: 0.6567 - val_loss: 1.3684 - val_acc: 0.6458
#
# Epoch 00001: val_acc improved from -inf to 0.64583, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 2/40
# 112/112 [==============================] - 25s 222ms/step - loss: 0.8189 - acc: 0.7148 - val_loss: 0.7899 - val_acc: 0.7448
#
# Epoch 00002: val_acc improved from 0.64583 to 0.74479, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 3/40
# 112/112 [==============================] - 25s 221ms/step - loss: 0.7460 - acc: 0.7226 - val_loss: 0.8338 - val_acc: 0.7083
#
# Epoch 00003: val_acc did not improve from 0.74479
# Epoch 4/40
# 112/112 [==============================] - 24s 216ms/step - loss: 0.6435 - acc: 0.7694 - val_loss: 0.6977 - val_acc: 0.7734
#
# Epoch 00004: val_acc improved from 0.74479 to 0.77344, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 5/40
# 112/112 [==============================] - 25s 220ms/step - loss: 0.6119 - acc: 0.7769 - val_loss: 0.7677 - val_acc: 0.7318
#
# Epoch 00005: val_acc did not improve from 0.77344
# Epoch 6/40
# 112/112 [==============================] - 24s 218ms/step - loss: 0.5268 - acc: 0.8143 - val_loss: 0.6745 - val_acc: 0.7734
#
# Epoch 00006: val_acc did not improve from 0.77344
# Epoch 7/40
# 112/112 [==============================] - 25s 218ms/step - loss: 0.4984 - acc: 0.8267 - val_loss: 0.7671 - val_acc: 0.7812
#
# Epoch 00007: val_acc improved from 0.77344 to 0.78125, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 8/40
# 112/112 [==============================] - 25s 222ms/step - loss: 0.4579 - acc: 0.8314 - val_loss: 0.5703 - val_acc: 0.8073
#
# Epoch 00008: val_acc improved from 0.78125 to 0.80729, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 9/40
# 112/112 [==============================] - 26s 230ms/step - loss: 0.4343 - acc: 0.8422 - val_loss: 0.6507 - val_acc: 0.7812
#
# Epoch 00009: val_acc did not improve from 0.80729
# Epoch 10/40
# 112/112 [==============================] - 25s 223ms/step - loss: 0.3988 - acc: 0.8588 - val_loss: 0.6410 - val_acc: 0.7995
#
# Epoch 00010: val_acc did not improve from 0.80729
# Epoch 11/40
# 112/112 [==============================] - 25s 220ms/step - loss: 0.3690 - acc: 0.8645 - val_loss: 0.7228 - val_acc: 0.8151
#
# Epoch 00011: val_acc improved from 0.80729 to 0.81510, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 12/40
# 112/112 [==============================] - 25s 222ms/step - loss: 0.3372 - acc: 0.8772 - val_loss: 0.9110 - val_acc: 0.7604
#
# Epoch 00012: val_acc did not improve from 0.81510
# Epoch 13/40
# 112/112 [==============================] - 24s 214ms/step - loss: 0.3269 - acc: 0.8833 - val_loss: 0.8307 - val_acc: 0.7865
#
# Epoch 00013: val_acc did not improve from 0.81510
# Epoch 14/40
# 112/112 [==============================] - 24s 217ms/step - loss: 0.2898 - acc: 0.8921 - val_loss: 0.6295 - val_acc: 0.7995
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 00014: val_acc did not improve from 0.81510
# Epoch 15/40
# 112/112 [==============================] - 25s 227ms/step - loss: 0.2618 - acc: 0.9041 - val_loss: 0.6438 - val_acc: 0.8125
#
# Epoch 00015: val_acc did not improve from 0.81510
# Epoch 16/40
# 112/112 [==============================] - 26s 231ms/step - loss: 0.2402 - acc: 0.9104 - val_loss: 0.7026 - val_acc: 0.8281
#
# Epoch 00016: val_acc improved from 0.81510 to 0.82812, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 17/40
# 112/112 [==============================] - 25s 225ms/step - loss: 0.2099 - acc: 0.9209 - val_loss: 0.5700 - val_acc: 0.8620
#
# Epoch 00017: val_acc improved from 0.82812 to 0.86198, saving model to /content/drive/MyDrive/cancer_skin/checkpoint.h5
# Epoch 18/40
# 112/112 [==============================] - 25s 223ms/step - loss: 0.2031 - acc: 0.9262 - val_loss: 0.5798 - val_acc: 0.8255
#
# Epoch 00018: val_acc did not improve from 0.86198
# Epoch 19/40
# 112/112 [==============================] - 25s 219ms/step - loss: 0.1839 - acc: 0.9324 - val_loss: 0.5773 - val_acc: 0.8542
#
# Epoch 00019: val_acc did not improve from 0.86198
# Epoch 20/40
# 112/112 [==============================] - 24s 215ms/step - loss: 0.1763 - acc: 0.9384 - val_loss: 0.8291 - val_acc: 0.8229
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 00020: val_acc did not improve from 0.86198
# Epoch 21/40
# 112/112 [==============================] - 24s 214ms/step - loss: 0.1569 - acc: 0.9461 - val_loss: 0.6860 - val_acc: 0.8333
#
# Epoch 00021: val_acc did not improve from 0.86198
# Epoch 22/40
# 112/112 [==============================] - 24s 215ms/step - loss: 0.1469 - acc: 0.9487 - val_loss: 0.5685 - val_acc: 0.8385
#
# Epoch 00022: val_acc did not improve from 0.86198
# Epoch 23/40
# 112/112 [==============================] - 24s 215ms/step - loss: 0.1366 - acc: 0.9503 - val_loss: 0.6148 - val_acc: 0.8385
#
# Epoch 00023: val_acc did not improve from 0.86198
# Epoch 24/40
# 112/112 [==============================] - 24s 213ms/step - loss: 0.1353 - acc: 0.9508 - val_loss: 0.6913 - val_acc: 0.8307
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 00024: val_acc did not improve from 0.86198
# Epoch 25/40
# 112/112 [==============================] - 24s 212ms/step - loss: 0.1226 - acc: 0.9585 - val_loss: 0.7877 - val_acc: 0.8255
#
# Epoch 00025: val_acc did not improve from 0.86198
# Epoch 26/40
# 112/112 [==============================] - 25s 222ms/step - loss: 0.1133 - acc: 0.9590 - val_loss: 0.7573 - val_acc: 0.8177
#
# Epoch 00026: val_acc did not improve from 0.86198
# Epoch 27/40
# 112/112 [==============================] - 25s 223ms/step - loss: 0.1127 - acc: 0.9604 - val_loss: 0.7257 - val_acc: 0.8307
#
# Epoch 00027: val_acc did not improve from 0.86198
# Epoch 28/40
# 112/112 [==============================] - 25s 223ms/step - loss: 0.1015 - acc: 0.9645 - val_loss: 0.7316 - val_acc: 0.8464
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 00028: val_acc did not improve from 0.86198
# Epoch 29/40
# 112/112 [==============================] - 25s 226ms/step - loss: 0.1117 - acc: 0.9649 - val_loss: 0.8125 - val_acc: 0.8464
#
# Epoch 00029: val_acc did not improve from 0.86198
# Epoch 30/40
# 112/112 [==============================] - 25s 224ms/step - loss: 0.1093 - acc: 0.9632 - val_loss: 0.6324 - val_acc: 0.8464
#
# Epoch 00030: val_acc did not improve from 0.86198
# Epoch 31/40
# 112/112 [==============================] - 25s 225ms/step - loss: 0.0977 - acc: 0.9649 - val_loss: 0.6553 - val_acc: 0.8516
#
# Epoch 00031: val_acc did not improve from 0.86198
# Epoch 32/40
# 112/112 [==============================] - 25s 222ms/step - loss: 0.0986 - acc: 0.9651 - val_loss: 0.7367 - val_acc: 0.8516
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 00032: val_acc did not improve from 0.86198
# Epoch 00032: early stopping

# %%
scores=model.evaluate(X_test,Y_test)
print("Test başarı oran:%{:.2f}".format(scores[1]*100))

scores=model.evaluate(X_val,Y_val)
print("Validation başarı oran:%{:.2f}".format(scores[1]*100))
# Out:
# 63/63 [==============================] - 8s 22ms/step - loss: 0.5736 - acc: 0.8597
# Test başarı oran:%85.97
# 26/26 [==============================] - 1s 29ms/step - loss: 0.7496 - acc: 0.8379
# Validation başarı oran:%83.79

# %%
print(history.history.keys())

plt.plot(history.history['acc'],'ro-')
plt.plot(history.history['val_acc'] , 'go-')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.savefig('/content/drive/MyDrive/cancer_skin/sonuc/acc_v3.png',dpi=300)
plt.show()

plt.plot(history.history['loss'] ,'ro-')
plt.plot(history.history['val_loss'], 'go-')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.savefig('/content/drive/MyDrive/cancer_skin/sonuc/loss_v3.png',dpi=300)
plt.show()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
matrix = metrics.confusion_matrix(Y_test.argmax(axis=1), y_pred.argmax(axis=1))


cm_df = pd.DataFrame(matrix,
                     index = ['Actinic keratoses','Basal cell carcinoma','Benign keratosis', 'Dermatofibroma','Melanoma','Melanocytic nevi','Vascular lesions'], 
                     columns = ['Actinic keratoses','Basal cell carcinoma','Benign keratosis', 'Dermatofibroma','Melanoma','Melanocytic nevi','Vascular lesions'])

plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray",fmt= '.1f')
plt.title('Confusion Matrix'); 
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.savefig('/content/drive/MyDrive/cancer_skin/sonuc/cm_v3.png',dpi=300)
plt.show()


#  One-hot encoding the classes
y_pred_classes = np.argmax(y_pred, axis = 1) 
# Gerçek etiketin çıkarılması
Y_true_classes = np.argmax(Y_test, axis = 1) 
print(confusion_matrix(Y_true_classes, y_pred_classes))
# Out:
# [[  40    2   17    1    4    0    0]
#  [   1   67   11    3    5    9    4]
#  [   4    2  170    1   19   31    1]
#  [   0    0    1   27    0    0    0]
#  [   4    0   21    2  119   67    0]
#  [   0    1   39    2   28 1278    0]
#  [   0    0    0    0    1    0   21]]

# %%
y_pred = model.predict(X_test)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(y_pred)):
    if np.argmax(y_pred[i]) == np.argmax(Y_test[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Toplam test verileri;', total, '\t doğru-tahmin edilmiş-veri:', accurate, '\t yanlış tahmin edilmiş veri: ', total - accurate)

print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Toplam test verileri; 2003 	 doğru-tahmin edilmiş-veri: 1722 	 yanlış tahmin edilmiş veri:  281
# Accuracy: 85.971 %

# %%
y_pred  = model.predict(X_test).round()
correct = np.nonzero(y_pred == Y_test)[0]
plt.figure(figsize=(16,16))
k = 0
for c in correct[:48]:
            plt.subplot(6,8,k+1)
            plt.imshow(X_test[k].reshape(128,128,3) , interpolation='none')
            plt.title(f"Gerçek :{Y_test[k].argmax(axis = 0)} ,pred :{y_pred[k].argmax(axis = 0)}")
            k +=1 
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/cancer_skin/sonuc/final_figure_v3.png',dpi=300)
plt.show()

# %%
from sklearn.metrics import roc_curve
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred,axis=1)
y_test_cm = np.argmax(Y_test,axis=1)
#confusion_matrix(y_test_cm,y_pred)

# ROC GRAFİĞİ

fpr = dict()
tpr = dict()
roc_auc = dict()

y_pred_e = to_categorical(y_pred)

from sklearn.metrics import auc, roc_auc_score,roc_curve
from itertools import cycle

for i in range(len(Y_test[0])):
    fpr[i],tpr[i],_ = roc_curve(Y_test[:,i],y_pred_e[:,i])
    roc_auc[i] = auc(fpr[i],tpr[i])

print(Y_test[0])

fpr["micro"],tpr["micro"],_ = roc_curve(Y_test.ravel(),y_pred_e.ravel())
roc_auc["micro"] = auc(fpr["micro"],tpr["micro"])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(len(Y_test[0]))]))

mean_tpr = np.zeros_like(all_fpr)


for i in range(len(Y_test[0])):
    mean_tpr += np.interp(all_fpr,fpr[i],tpr[i])



mean_tpr /= len(Y_test[0])

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"],tpr["macro"])

plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(len(Y_test[i])), colors):
    plt.plot(fpr[i], tpr[i], color=color,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.savefig('/content/drive/MyDrive/cancer_skin/sonuc/roc_v3.png',dpi=300)
plt.show()


labels = ['0-akiec', '1-bcc', '2-bkl', '3-df', '4-mel','5-nv', '6-vasc']
cr = "\n\nSINIFLANDIRMA RAPORU\n---------------------\n"
cr += classification_report(y_test_cm,y_pred, target_names=labels)
print(cr)
# Out:
# [0. 0. 0. 0. 0. 1. 0.]
# SINIFLANDIRMA RAPORU
# ---------------------
#               precision    recall  f1-score   support
#
#      0-akiec       0.82      0.62      0.71        64
#        1-bcc       0.93      0.67      0.78       100
#        2-bkl       0.66      0.75      0.70       228
#         3-df       0.75      0.96      0.84        28
#        4-mel       0.68      0.56      0.61       213
#         5-nv       0.92      0.95      0.94      1348
#       6-vasc       0.81      0.95      0.88        22
#
#     accuracy                           0.86      2003
#    macro avg       0.79      0.78      0.78      2003
# weighted avg       0.86      0.86      0.86      2003

# %%
from keras.models import load_model
model = load_model("/content/drive/MyDrive/cancer_skin/InceptionV3.h5")
scores=model.evaluate(X_test,Y_test)
print("Test başarı oran:%{:.2f}".format(scores[1]*100))

scores=model.evaluate(X_val,Y_val)
print("Validation başarı oran:%{:.2f}".format(scores[1]*100))
# Out:
# 63/63 [==============================] - 7s 16ms/step - loss: 0.5736 - acc: 0.8597
# Test başarı oran:%85.97
# 26/26 [==============================] - 0s 16ms/step - loss: 0.7496 - acc: 0.8379
# Validation başarı oran:%83.79
